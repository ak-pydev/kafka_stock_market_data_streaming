# %%
import pandas as pd 
from kafka import KafkaConsumer
from time import sleep
from json import loads
import json
from s3fs import S3FileSystem

# %%
consumer = KafkaConsumer('test-topic',bootstrap_servers=['100.24.38.29:9092'], 
                         value_deserializer=lambda x: loads(x.decode('utf-8')))

# %%
s3 = S3FileSystem()

# %%
for count, msg in enumerate(consumer):
    s3_path = f"s3://stockstreamin2/stock_market_{count}.json"
    
    with s3.open(s3_path, 'w') as f:
        f.write(json.dumps(msg.value))

    print(f"Saved: {s3_path}")
# Out:
# Saved: s3://stockstreamin2/stock_market_356.json
# Saved: s3://stockstreamin2/stock_market_357.json
# Saved: s3://stockstreamin2/stock_market_358.json
# Saved: s3://stockstreamin2/stock_market_359.json
# Saved: s3://stockstreamin2/stock_market_360.json
# Saved: s3://stockstreamin2/stock_market_361.json
# Saved: s3://stockstreamin2/stock_market_362.json
# Saved: s3://stockstreamin2/stock_market_363.json
# Saved: s3://stockstreamin2/stock_market_364.json
# Saved: s3://stockstreamin2/stock_market_365.json
# Saved: s3://stockstreamin2/stock_market_366.json
# Saved: s3://stockstreamin2/stock_market_367.json
# Saved: s3://stockstreamin2/stock_market_368.json
# Saved: s3://stockstreamin2/stock_market_369.json
# Saved: s3://stockstreamin2/stock_market_370.json
# Saved: s3://stockstreamin2/stock_market_371.json
# Saved: s3://stockstreamin2/stock_market_372.json
# Saved: s3://stockstreamin2/stock_market_373.json
# Saved: s3://stockstreamin2/stock_market_374.json
# ...
