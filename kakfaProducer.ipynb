# %%
import pandas as pd 
from kafka import KafkaConsumer, KafkaProducer
from time import sleep
from json import dumps
import json

# %%
producer = KafkaProducer(bootstrap_servers=['100.24.38.29:9092'], 
                         value_serializer=lambda x: 
                         dumps(x).encode('utf-8'))

# %%
producer.send('test-topic', value = {'name': 'Aaditya'}) # running check

# %%
df = pd.read_csv('indexProcessed.csv')

# %%
while True:
    dict_stock = df.sample(1).to_dict(orient='records')[0]
    producer.send('test-topic', value=dict_stock)
    sleep(1)
print("Terminated")

# %%
producer.flush()
